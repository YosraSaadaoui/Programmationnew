# %%
import pandas as pd
import numpy as np

 

data = {'A': [11, 22, 33],
        'B': [44, 55, 66],
        'C': [77, 88, 99]
        }

 

df = pd.DataFrame(data, columns = ['A', 'B', 'C'])
df
# Out:
#     A   B   C
# 0  11  44  77
# 1  22  55  88
# 2  33  66  99

# %%
df.rolling(window=2).C.sum()
# Out:
# 0      NaN
# 1    165.0
# 2    187.0
# Name: C, dtype: float64

# %%
df=pd.read_csv('C:/Users/thinkbook/Documents/GitHub/Programmation2/data/complete.csv')

# %%
df.head()
# Out:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
#
#                                     categoryFullName  sortOrder portion  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 1                         The Nobel Prize in Physics          1     1/3
# 2                       The Nobel Prize in Chemistry          1     1/3
# 3                       The Nobel Prize in Chemistry          1       1
# 4                         The Nobel Prize in Physics          2     1/3
#
#    prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0     10000000             12295082  2001-10-10    received
# 1       630000              3404179  1975-10-17    received
# 2     10000000             11762861  2004-10-06    received
# 3      1150000              3102518  1982-10-18    received
# ...

# %%
df = df[['awardYear', 'category', 'prizeAmount', 'prizeAmountAdjusted', 'name', 'gender', 'birth_continent']]

# %%
df.head()
# Out:
#    awardYear           category  prizeAmount  prizeAmountAdjusted  \
# 0       2001  Economic Sciences     10000000             12295082
# 1       1975            Physics       630000              3404179
# 2       2004          Chemistry     10000000             11762861
# 3       1982          Chemistry      1150000              3102518
# 4       1979            Physics       800000              2988048
#
#                 name gender birth_continent
# 0  A. Michael Spence   male   North America
# 1       Aage N. Bohr   male          Europe
# 2  Aaron Ciechanover   male            Asia
# 3         Aaron Klug   male          Europe
# 4        Abdus Salam   male            Asia

# %%
grouped=df.groupby('category')
print(grouped)

# %%
grouped_category_year=df.groupby(['category','awardYear'])

# %%
print(grouped.ngroups)
# Out:
# 6

# %%
grouped.get_group('Economic Sciences')
# Out:
#      awardYear           category  prizeAmount  prizeAmountAdjusted  \
# 0         2001  Economic Sciences     10000000             12295082
# 5         2019  Economic Sciences      9000000              9000000
# 45        2012  Economic Sciences      8000000              8361204
# 46        1998  Economic Sciences      7600000              9713701
# 58        2015  Economic Sciences      8000000              8384572
# ..         ...                ...          ...                  ...
# 882       2002  Economic Sciences     10000000             12034660
# 896       1973  Economic Sciences       510000              3331882
# 912       2018  Economic Sciences      9000000              9000000
# 916       1990  Economic Sciences      4000000              6329114
# 924       1996  Economic Sciences      7400000              9490424
#
#                     name gender birth_continent
# 0      A. Michael Spence   male   North America
# 5       Abhijit Banerjee   male            Asia
# ...

# %%
grouped.mean()
# Out:
# C:\Users\thinkbook\AppData\Local\Temp\ipykernel_14116\2755795945.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean()
#                           awardYear   prizeAmount  prizeAmountAdjusted
# category
# Chemistry               1972.347826  3.629279e+06         6.257868e+06
# Economic Sciences       1996.119048  6.105845e+06         7.837779e+06
# Literature              1960.931034  2.493811e+06         5.598256e+06
# Peace                   1964.537313  3.124879e+06         6.163907e+06
# Physics                 1971.065728  3.407939e+06         6.086978e+06
# Physiology or Medicine  1970.356164  3.072973e+06         5.738301e+06

# %%
left = pd.DataFrame(
    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"]
)

 


right = pd.DataFrame(
    {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"]
)

# %%
result=left.join(right, how='left')

# %%
result
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
import pandas as pd
chart = {'Name':['Chetan','yashas','yuvraj'],'Age':  [20, 25, 30],'Height': [155, 160, 175],'Weight': [55,60,75]}
df = pd.DataFrame(chart)
df
# Out:
#      Name  Age  Height  Weight
# 0  Chetan   20     155      55
# 1  yashas   25     160      60
# 2  yuvraj   30     175      75

# %%
df.corr(method='pearson')
# Out:
# C:\Users\thinkbook\AppData\Local\Temp\ipykernel_14116\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#              Age    Height    Weight
# Age     1.000000  0.960769  0.960769
# Height  0.960769  1.000000  1.000000
# Weight  0.960769  1.000000  1.000000

# %%
df = pd.read_csv("https://raw.githubusercontent.com/bprasad26/lwd/master/data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(subset=['Age'],inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
bins= [0,14,24,64,100]
bin_labels= ['Children','Youth','Adults','Senior']
df['AgeCat']= pd.cut(df['Age'], bins = bins, labels = bin_labels)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
