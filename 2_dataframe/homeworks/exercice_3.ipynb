# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\thinkbook\Documents\GitHub\Programmation2\data\nyc-parking-violations-2020.csv',
                
               usecols=['Date First Observed','Plate ID','Registration State','Issue Date','Vehicle Make','Street Name','Vehicle Color'],
              )

# %%
df.head()
# Out:
#   Plate ID Registration State              Issue Date Vehicle Make  \
# 0   J58JKX                 NJ  05/08/1972 12:00:00 AM        HONDA
# 1  KRE6058                 PA  08/29/1977 12:00:00 AM        ME/BE
# 2  444326R                 NJ  10/03/1988 12:00:00 AM        LEXUS
# 3  F728330                 OH  01/03/1990 12:00:00 AM        CHEVR
# 4  FMY9090                 NY  02/14/1990 12:00:00 AM         JEEP
#
#        Street Name  Date First Observed Vehicle Color
# 0            43 ST                    0            BK
# 1         UNION ST                    0           BLK
# 2  CLERMONT AVENUE                    0         BLACK
# 3     DIVISION AVE                    0           NaN
# 4         GRAND ST                    0          GREY

# %%
df
# Out:
#           Plate ID Registration State              Issue Date Vehicle Make  \
# 0           J58JKX                 NJ  05/08/1972 12:00:00 AM        HONDA
# 1          KRE6058                 PA  08/29/1977 12:00:00 AM        ME/BE
# 2          444326R                 NJ  10/03/1988 12:00:00 AM        LEXUS
# 3          F728330                 OH  01/03/1990 12:00:00 AM        CHEVR
# 4          FMY9090                 NY  02/14/1990 12:00:00 AM         JEEP
# ...            ...                ...                     ...          ...
# 12495729   62161MM                 NY  01/03/2040 12:00:00 AM         FORD
# 12495730   GYE7330                 NY  04/19/2045 12:00:00 AM        HONDA
# 12495731   HNY4802                 NY  01/17/2049 12:00:00 AM         FORD
# 12495732  T687081C                 NY  12/19/2063 12:00:00 AM        TOYOT
# 12495733    3497ZN                 WA  06/04/2064 12:00:00 AM        UTILI
#
#                Street Name  Date First Observed Vehicle Color
# ...

# %% [markdown]
# ### Question 2

# %%
df1=df.set_index('Issue Date')
df1
# Out:
#                         Plate ID Registration State Vehicle Make  \
# Issue Date
# 05/08/1972 12:00:00 AM    J58JKX                 NJ        HONDA
# 08/29/1977 12:00:00 AM   KRE6058                 PA        ME/BE
# 10/03/1988 12:00:00 AM   444326R                 NJ        LEXUS
# 01/03/1990 12:00:00 AM   F728330                 OH        CHEVR
# 02/14/1990 12:00:00 AM   FMY9090                 NY         JEEP
# ...                          ...                ...          ...
# 01/03/2040 12:00:00 AM   62161MM                 NY         FORD
# 04/19/2045 12:00:00 AM   GYE7330                 NY        HONDA
# 01/17/2049 12:00:00 AM   HNY4802                 NY         FORD
# 12/19/2063 12:00:00 AM  T687081C                 NY        TOYOT
# 06/04/2064 12:00:00 AM    3497ZN                 WA        UTILI
#
#                              Street Name  Date First Observed Vehicle Color
# Issue Date
# 05/08/1972 12:00:00 AM             43 ST                    0            BK
# ...

# %%
df1.shape
# Out:
# (12495734, 6)

# %% [markdown]
# ### Question 3

# %%
df2=df1.loc[('12/19/2063 12:00:00 AM','Vehicle Make')]

# %%
df2.value_counts()
df2.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df2.value_counts()
#       2 df2.head(3)
#
# AttributeError: 'str' object has no attribute 'value_counts'

# %% [markdown]
# ### question 4

# %%
df3=df1.loc[('06/01/2020 12:00:00 AM','Street Name')]
#df3["Street Name"].value_counts()
#df3.head(5)
df3
# Out:
# Issue Date
# 06/01/2020 12:00:00 AM    SB 2 Avenue @ E 93 S
# 06/01/2020 12:00:00 AM    SB 2 Avenue @ E 63 S
# 06/01/2020 12:00:00 AM    SB 2 Avenue @ E 69 S
# 06/01/2020 12:00:00 AM    SB 2 Avenue @ E 78 S
# 06/01/2020 12:00:00 AM    SB 2 Avenue @ E 21 S
#                                   ...
# 06/01/2020 12:00:00 AM           CENTRE STREET
# 06/01/2020 12:00:00 AM             ELGAR PLACE
# 06/01/2020 12:00:00 AM                 29TH ST
# 06/01/2020 12:00:00 AM                CLARKSON
# 06/01/2020 12:00:00 AM                 8TH AVE
# Name: Street Name, Length: 22863, dtype: object

# %% [markdown]
# ### question 5

# %%
df5=df.set_index('Vehicle Color')
df5
# Out:
#                Plate ID Registration State              Issue Date  \
# Vehicle Color
# BK               J58JKX                 NJ  05/08/1972 12:00:00 AM
# BLK             KRE6058                 PA  08/29/1977 12:00:00 AM
# BLACK           444326R                 NJ  10/03/1988 12:00:00 AM
# NaN             F728330                 OH  01/03/1990 12:00:00 AM
# GREY            FMY9090                 NY  02/14/1990 12:00:00 AM
# ...                 ...                ...                     ...
# BR              62161MM                 NY  01/03/2040 12:00:00 AM
# BLK             GYE7330                 NY  04/19/2045 12:00:00 AM
# GY              HNY4802                 NY  01/17/2049 12:00:00 AM
# BLK            T687081C                 NY  12/19/2063 12:00:00 AM
# WHITE            3497ZN                 WA  06/04/2064 12:00:00 AM
#
#               Vehicle Make       Street Name  Date First Observed
# Vehicle Color
# ...

# %% [markdown]
# ### question 6

# %%
df6=df4.loc[('Vehicle colour', is in
df6.value_count()
df6.head(5)
