# %%
import pandas as pd

# %%
filenames = ['C:/Users/thinkbook/Desktop/programmation2/nyc_taxi_2020-01.csv', 'C:/Users/thinkbook/Desktop/programmation2/nyc_taxi_2020-07.csv']
all_dfs = []
for one_filename in filenames:
    print(one_filename)
    all_dfs.append(pd.read_csv(one_filename, usecols = ['tpep_pickup_datetime', 'passenger_count', 'trip_distance', 'fare_amount','extra','mta_tax','tip_amount','tolls_amount', 'improvement_surcharge','total_amount','congestion_surcharge'], 
                               parse_dates = ['tpep_pickup_datetime']))
# Out:
# C:/Users/thinkbook/Desktop/programmation2/nyc_taxi_2020-01.csv
# C:/Users/thinkbook/Desktop/programmation2/nyc_taxi_2020-07.csv

# %%
df=pd.concat(all_dfs)
df
# Out:
#        tpep_pickup_datetime  passenger_count  trip_distance  fare_amount  \
# 0       2020-01-01 00:28:15              1.0           1.20         6.00
# 1       2020-01-01 00:35:39              1.0           1.20         7.00
# 2       2020-01-01 00:47:41              1.0           0.60         6.00
# 3       2020-01-01 00:55:23              1.0           0.80         5.50
# 4       2020-01-01 00:01:58              1.0           0.00         3.50
# ...                     ...              ...            ...          ...
# 800407  2020-07-19 13:27:52              NaN          24.23        79.95
# 800408  2020-07-19 13:02:00              NaN           4.40        16.23
# 800409  2020-07-19 13:32:00              NaN           8.78        34.90
# 800410  2020-07-19 13:28:00              NaN           6.50        18.75
# 800411  2020-07-19 13:31:23              NaN          10.88        48.35
#
#         extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# ...

# %%
df['year']=df['tpep_pickup_datetime'].dt.year
df
# Out:
#        tpep_pickup_datetime  passenger_count  trip_distance  fare_amount  \
# 0       2020-01-01 00:28:15              1.0           1.20         6.00
# 1       2020-01-01 00:35:39              1.0           1.20         7.00
# 2       2020-01-01 00:47:41              1.0           0.60         6.00
# 3       2020-01-01 00:55:23              1.0           0.80         5.50
# 4       2020-01-01 00:01:58              1.0           0.00         3.50
# ...                     ...              ...            ...          ...
# 800407  2020-07-19 13:27:52              NaN          24.23        79.95
# 800408  2020-07-19 13:02:00              NaN           4.40        16.23
# 800409  2020-07-19 13:32:00              NaN           8.78        34.90
# 800410  2020-07-19 13:28:00              NaN           6.50        18.75
# 800411  2020-07-19 13:31:23              NaN          10.88        48.35
#
#         extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# ...

# %%
df['month']=df['tpep_pickup_datetime'].dt.month
df
# Out:
#        tpep_pickup_datetime  passenger_count  trip_distance  fare_amount  \
# 0       2020-01-01 00:28:15              1.0           1.20         6.00
# 1       2020-01-01 00:35:39              1.0           1.20         7.00
# 2       2020-01-01 00:47:41              1.0           0.60         6.00
# 3       2020-01-01 00:55:23              1.0           0.80         5.50
# 4       2020-01-01 00:01:58              1.0           0.00         3.50
# ...                     ...              ...            ...          ...
# 800407  2020-07-19 13:27:52              NaN          24.23        79.95
# 800408  2020-07-19 13:02:00              NaN           4.40        16.23
# 800409  2020-07-19 13:32:00              NaN           8.78        34.90
# 800410  2020-07-19 13:28:00              NaN           6.50        18.75
# 800411  2020-07-19 13:31:23              NaN          10.88        48.35
#
#         extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# ...

# %%
df['day']=df['tpep_pickup_datetime'].dt.day

# %%
df=df[((df.month==1)|(df.month==7)) &(df.year==2020)]
df
# Out:
#        tpep_pickup_datetime  passenger_count  trip_distance  fare_amount  \
# 0       2020-01-01 00:28:15              1.0           1.20         6.00
# 1       2020-01-01 00:35:39              1.0           1.20         7.00
# 2       2020-01-01 00:47:41              1.0           0.60         6.00
# 3       2020-01-01 00:55:23              1.0           0.80         5.50
# 4       2020-01-01 00:01:58              1.0           0.00         3.50
# ...                     ...              ...            ...          ...
# 800407  2020-07-19 13:27:52              NaN          24.23        79.95
# 800408  2020-07-19 13:02:00              NaN           4.40        16.23
# 800409  2020-07-19 13:32:00              NaN           8.78        34.90
# 800410  2020-07-19 13:28:00              NaN           6.50        18.75
# 800411  2020-07-19 13:31:23              NaN          10.88        48.35
#
#         extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#         tpep_pickup_datetime  passenger_count  trip_distance  fare_amount  \
# 0        2020-01-01 00:28:15              1.0           1.20         6.00
# 1        2020-01-01 00:35:39              1.0           1.20         7.00
# 2        2020-01-01 00:47:41              1.0           0.60         6.00
# 3        2020-01-01 00:55:23              1.0           0.80         5.50
# 4        2020-01-01 00:01:58              1.0           0.00         3.50
# ...                      ...              ...            ...          ...
# 7205199  2020-07-19 13:27:52              NaN          24.23        79.95
# 7205200  2020-07-19 13:02:00              NaN           4.40        16.23
# 7205201  2020-07-19 13:32:00              NaN           8.78        34.90
# 7205202  2020-07-19 13:28:00              NaN           6.50        18.75
# 7205203  2020-07-19 13:31:23              NaN          10.88        48.35
#
#          extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# ...

# %%
df=df.sample(frac=0.01)

# %%
df
# Out:
#         tpep_pickup_datetime  passenger_count  trip_distance  fare_amount  \
# 2770460  2020-01-15 10:17:37              1.0          15.01         41.5
# 4857363  2020-01-25 04:12:44              1.0           1.18          6.0
# 4861506  2020-01-25 06:28:11              1.0          11.28         32.0
# 415522   2020-01-03 15:14:29              1.0           3.69         15.0
# 6175772  2020-01-31 11:59:09              1.0           8.90         28.0
# ...                      ...              ...            ...          ...
# 1486146  2020-01-09 09:16:26              1.0           0.50          5.5
# 3007748  2020-01-16 12:47:02              6.0           2.35         11.5
# 747791   2020-01-05 11:04:03              1.0           4.81         15.0
# 5999466  2020-01-30 16:50:07              1.0           8.98         29.0
# 4264487  2020-01-22 16:06:58              1.0           0.80          6.5
#
#          extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# ...

# %%
import seaborn as sns

# %%
sns.relplot(x='trip_distance', y='total_amount' ,data=df, hue='passenger_count')
import matplotlib.pyplot as plt
plt.title('total amount vs trip_distance')
plt.xlabel('les distance')
# Out:
# Text(0.5, 28.999999999999986, 'les distance')

# %%
import matplotlib.pyplot as plt
plt.title('total amount vs trip_distance')
plt.xlabel('les distance')
# Out:
# Text(0.5, 0, 'les distance')

# %%
sns.relplot(x='day', y='trip_distance', kind='line',data=df, hue='month',errorbar=None,style='month')

# %%
data1=df.groupby(['month','day']).year.count().to_frame()
data1
# Out:
#            year
# month day
# 1     1    1686
#       2    1645
#       3    1780
#       4    1831
#       5    1617
# ...         ...
# 7     27    293
#       28    321
#       29    365
#       30    294
#       31    328
#
# [62 rows x 1 columns]

# %%
sns.relplot(x='day', y='year', kind='line',data=data1, hue='month',errorbar=None,style='month')
