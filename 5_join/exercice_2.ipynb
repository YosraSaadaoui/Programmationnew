# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/thinkbook/Documents/GitHub/Programmation2/data/data chap6/oecd_tourism.csv', usecols=['LOCATION','SUBJECT','TIME','Value'])

# %%
df
# Out:
#      LOCATION  SUBJECT  TIME      Value
# 0         AUS  INT_REC  2008  31159.800
# 1         AUS  INT_REC  2009  29980.700
# 2         AUS  INT_REC  2010  35165.500
# 3         AUS  INT_REC  2011  38710.100
# 4         AUS  INT_REC  2012  38003.700
# ...       ...      ...   ...        ...
# 1229      SRB  INT-EXP  2015   1253.644
# 1230      SRB  INT-EXP  2016   1351.098
# 1231      SRB  INT-EXP  2017   1549.183
# 1232      SRB  INT-EXP  2018   1837.317
# 1233      SRB  INT-EXP  2019   1999.313
#
# [1234 rows x 4 columns]

# %%
df=df[df['SUBJECT']=='INT_REC']

# %%
df
# Out:
#      LOCATION  SUBJECT  TIME      Value
# 0         AUS  INT_REC  2008  31159.800
# 1         AUS  INT_REC  2009  29980.700
# 2         AUS  INT_REC  2010  35165.500
# 3         AUS  INT_REC  2011  38710.100
# 4         AUS  INT_REC  2012  38003.700
# ...       ...      ...   ...        ...
# 1217      SRB  INT_REC  2015   1321.638
# 1218      SRB  INT_REC  2016   1460.953
# 1219      SRB  INT_REC  2017   1706.146
# 1220      SRB  INT_REC  2018   1941.074
# 1221      SRB  INT_REC  2019   2000.579
#
# [617 rows x 4 columns]

# %%
df.groupby(['LOCATION'])['Value'].mean().sort_values(ascending=False).head()
# Out:
# LOCATION
# USA    201613.500000
# ESP     69655.817364
# FRA     65063.335727
# DEU     53408.570636
# GBR     51752.090909
# Name: Value, dtype: float64

# %%
df=df[df['SUBJECT']=='INT-EXP']
df.groupby(['LOCATION'])['Value'].mean().sort_values().head()
# Out:
# Series([], Name: Value, dtype: float64)

# %%
Documents/GitHub/Programmation2/data/data chap6/oecd_locations.csv',header=0,names=['LOCATION','NAME'], index_col='LOCATION')locations_df=pd.read_csv('C:/Users/thinkbook/
# Out:
#   Cell In[8], line 1
#     Documents/GitHub/Programmation2/data/data chap6/oecd_locations.csv',header=0,names=['LOCATION','NAME'], index_col='LOCATION')locations_df=pd.read_csv('C:/Users/thinkbook/
#                                               ^
# SyntaxError: invalid syntax

# %%
locations_df
# Out:
#                     NAME
# LOCATION
# AUT              Austria
# BEL              Belgium
# CAN               Canada
# DNK              Denmark
# FIN              Finland
# FRA               France
# DEU              Germany
# HUN              Hungary
# ITA                Italy
# JPN                Japan
# KOR                Korea
# GBR       United Kingdom
# USA        United States
# BRA               Brazil
# ISR               Israel

# %%
df1=df.set_index('LOCATION')

# %%
jointure=locations_df.join(df1)
jointure
# Out:
#                    NAME  SUBJECT  TIME     Value
# LOCATION
# AUT             Austria  INT_REC  2008   21499.2
# AUT             Austria  INT_REC  2009   19302.8
# AUT             Austria  INT_REC  2010   18577.7
# AUT             Austria  INT_REC  2011   19833.0
# AUT             Austria  INT_REC  2012   21390.4
# ...                 ...      ...   ...       ...
# USA       United States  INT-EXP  2015  144667.0
# USA       United States  INT-EXP  2016  147639.0
# USA       United States  INT-EXP  2017  158331.0
# USA       United States  INT-EXP  2018  172548.0
# USA       United States  INT-EXP  2019  182365.0
#
# [340 rows x 4 columns]

# %%
jointure[jointure.loc[:,'NAME']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 jointure[jointure.loc[:,'NAME']]
#
# File ~\.conda\envs\envP1\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\.conda\envs\envP1\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
# ...

# %%
jointure[jointure['SUBJECT']=='INT-EXP'].groupby(['NAME'])['Value'].mean().sort_values().head()
# Out:
# NAME
# Hungary     2918.390182
# Finland     5877.080909
# Israel      6726.524833
# Denmark    11326.169636
# Austria    11934.563636
# Name: Value, dtype: float64

# %%
jointure[jointure['SUBJECT']=='INT-EXP'].groupby(['TIME'])['Value'].mean().sort_values()
# Out:
# TIME
# 2009    33523.988533
# 2010    35552.321933
# 2015    37167.780067
# 2016    37616.339867
# 2008    37617.775867
# 2011    38594.182800
# 2012    38876.667667
# 2017    39510.809533
# 2013    39885.574333
# 2014    41262.057467
# 2018    42453.575933
# 2019    57348.799000
# Name: Value, dtype: float64

# %%
oecd_df = pd.read_csv('C:/Users/thinkbook/Documents/GitHub/Programmation2/data/data chap6/oecd_locations.csv', header=None, names=['abbrev', 'country'], index_col='abbrev')
oecd_df.head()
# Out:
#           country
# abbrev
# AUS     Australia
# AUT       Austria
# BEL       Belgium
# CAN        Canada
# DNK       Denmark

# %%
tourism_df=pd.read_csv('C:/Users/thinkbook/Documents/GitHub/Programmation2/data/data chap6/oecd_tourism.csv', usecols=['LOCATION','TIME','Value'])

# %%
fullname_df = locations_df.join(tourism_df.set_index('LOCATION'))
fullname_df
# Out:
#                    NAME  TIME     Value
# LOCATION
# AUT             Austria  2008   21499.2
# AUT             Austria  2009   19302.8
# AUT             Austria  2010   18577.7
# AUT             Austria  2011   19833.0
# AUT             Austria  2012   21390.4
# ...                 ...   ...       ...
# USA       United States  2015  144667.0
# USA       United States  2016  147639.0
# USA       United States  2017  158331.0
# USA       United States  2018  172548.0
# USA       United States  2019  182365.0
#
# [340 rows x 3 columns]
